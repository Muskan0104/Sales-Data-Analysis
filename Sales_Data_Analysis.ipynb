# %% [markdown]
# # =========================
# # 1. Importing Dependencies
# # =========================

# %%
print("\n==============================")
print("📦 IMPORTING LIBRARIES")
print("==============================\n")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

print("✅ Libraries loaded successfully\n")
# Out:
# ...
# 📦 IMPORTING LIBRARIES
# ...
#
# ✅ Libraries loaded successfully

# %% [markdown]
# # =========================
# # 2. DATA LOADING
# # =========================

# %%
print("\n==============================")
print("📂 DATA LOADING")
print("==============================\n")

df = pd.read_csv('Superstore.csv', encoding='latin1')

print("✅ Dataset loaded successfully\n")

print("🔹 First 5 rows:\n")
print(df.head())

print("\n🔹 Last 5 rows:\n")
print(df.tail())
# Out:
# ...
# 📂 DATA LOADING
# ...
#
# ✅ Dataset loaded successfully
#
# 🔹 First 5 rows:
#
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
# ...

# %% [markdown]
# # =========================
# # 3. DATA Understanding
# # =========================

# %%
print("\n==============================")
print("🔍 DATA UNDERSTANDING")
print("==============================\n")

print("📊 Shape of Dataset:", df.shape)

print("\n📌 Column Names:")
print(df.columns)

print("\n📋 Dataset Info:\n")
df.info()

print("\n📈 Statistical Summary:\n")
print(df.describe())
# Out:
# ...
# 🔍 DATA UNDERSTANDING
# ...
#
# 📊 Shape of Dataset: (9994, 21)
#
# 📌 Column Names:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
#
# 📋 Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
# ...

# %% [markdown]
# # =========================
# # 4. DATA Cleaning
# # =========================

# %%
print("\n==============================")
print("🧹 DATA CLEANING")
print("==============================\n")

print("❓ Missing Values:\n")
print(df.isnull().sum())

df.drop_duplicates(inplace=True)
print("\n✅ Duplicates removed successfully")
# Out:
# ...
# 🧹 DATA CLEANING
# ...
#
# ❓ Missing Values:
#
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64
#
# ✅ Duplicates removed successfully

# %% [markdown]
# # =========================
# # 5.Exploratory Data Analysis (EDA)
# # =========================

# %%
print("\n==============================")
print("📊 EXPLORATORY DATA ANALYSIS")
print("==============================\n")

total_sales = df['Sales'].sum()
total_profit = df['Profit'].sum()

print(f"📊 Total Sales: {total_sales:,.2f}")
print(f"💰 Total Profit: {total_profit:,.2f}")
# Out:
# ...
# 📊 EXPLORATORY DATA ANALYSIS
# ...
#
# 📊 Total Sales: 2,297,200.86
# 💰 Total Profit: 286,397.02

# %%
print("\n📦 Sales by Category:\n")

category_sales = df.groupby('Category')['Sales'].sum()
print(category_sales)
# Out:
# 📦 Sales by Category:
#
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %% [markdown]
# # =========================
# # 6. Visualization
# # =========================

# %%
print("\n==============================")
print("📈 VISUALIZATION")
print("==============================\n")

plt.figure(figsize=(6,4))
df.groupby('Category')['Sales'].sum().plot(kind='bar')

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.show()
# Out:
# ...
# 📈 VISUALIZATION
# ...

# %%
print("\n==============================")
print("🔍 INSIGHTS")
print("==============================\n")

print("1️⃣ Technology category has highest sales")
print("2️⃣ Some states contribute more to revenue")
print("3️⃣ Profit is not equal across categories")
# Out:
# ...
# 🔍 INSIGHTS
# ...
#
# 1️⃣ Technology category has highest sales
# 2️⃣ Some states contribute more to revenue
# 3️⃣ Profit is not equal across categories

# %%
print("\n==============================")
print("🏁 CONCLUSION")
print("==============================\n")

print("This project analyzed sales data and identified key business insights.")
# Out:
# ...
# 🏁 CONCLUSION
# ...
#
# This project analyzed sales data and identified key business insights.
